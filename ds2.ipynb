# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x=np.array([1,3,5,7])
y=np.array([5,4,6,8])

plt.plot(x,y)
plt.show()

# %%
x=np.array([1,8])
y=np.array([3,10])
font1={'family':'serif','color':'red'}
plt.plot(x,y,'o:b',mec='r')
plt.xlabel("avg")
plt.title("demo",fontdict=font1)
plt.show()

# %%
x=np.array([1,6,3,9])
y=np.array([5,2,9,0])

plt.subplot(3,2,1)
plt.plot(x,y)
plt.show()

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 2, 2)
plt.plot(x,y)
plt.show()

x=np.array([1,6,3,9])
y=np.array([5,2,9,0])

plt.subplot(3,2,3)
plt.plot(x,y)
plt.show()

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 2, 4)
plt.plot(x,y)
plt.show()

x=np.array([1,6,3,9])
y=np.array([5,2,9,0])

plt.subplot(3,2,5)
plt.plot(x,y)
plt.show()

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 2, 6)
plt.plot(x,y)
plt.show()

# %%
x=np.array([1,6,3,9])
y=np.array([5,2,9,0])
plt.scatter(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,cmap='nipy_spectral')
plt.colorbar()
plt.show()
# Out:
# C:\Users\cclab31\AppData\Local\Temp\ipykernel_7088\1073446708.py:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y,cmap='nipy_spectral')

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0, 0.1, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.legend()
plt.show()
